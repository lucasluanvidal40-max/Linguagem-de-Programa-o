# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasluanvidal40-max/Linguagem-de-Programa-o/blob/main/Linguagem_de_Programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## U1_A1

# %%
print('hello world')
# Out:
# hello world

# %%
nome= 'lucas'
nota= 0.70
x= 10
fez_inscrecao= True

# %%
print (nome)
print (nota)
print (x)
print (fez_inscrecao)
# Out:
# lucas
# 0.7
# 10
# True

# %%
print (type(x))
print (type(nome))
print (type(nota))
print (type(fez_inscrecao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome=input('qual é o seu nome? ')
nota=input('qual é a sua nota? ')
media=float(nota)/2
print(media)
# Out:
# qual é o seu nome? lucas
# qual é a sua nota? 7
# 3.5

# %%
nota_1=float(input('digite a primeira nota: '))
nota_2=float(input('digite a segunda nota: '))
nmot_3=float(input('digite a terceira nota: '))
nota_4=float(input('digite a quarta nota: '))
media=(nota_1+nota_2+nmot_3+nota_4)/4
print(media)
# Out:
# digite a primeira nota: 8
# digite a segunda nota: 9
# digite a terceira nota: 10
# digite a quarta nota: 6
# 8.25

# %%
if media >= 6:
    situacao='aprovado'
else:
    situacao='reprovado'
print(situacao)
# Out:
# aprovado

# %% [markdown]
# U

# %% [markdown]
# # U1_A2 ####

# %%
print(10>5)
# Out:
# True

# %%
print(5>10)
# Out:
# False

# %%
print(7==7)
# Out:
# True

# %%
print(7!=7)
# Out:
# False

# %%
idade=int(input('digite sua idade: '))
if idade >= 18:
    print('maior de idade')
elif idade >= 18 and idade <= 60:
    print('adulto')
    if idade >= 60:
        print('idoso')
else:
    print('menor de idade')
# Out:
# digite sua idade: 23
# maior de idade

# %%
 idade= int(input('digite sua idade: '))
 if idade >= 12 and idade <18:
    print('recomendamos o filme infatil.')
elif idade >= 18 and idade <60:
    print('recomendamos o filme adulto.')
else:
    print('recomendamos o filme para idosos.')
# Out:
# digite sua idade: 15
# recomendamos o filme infatil.

# %%
quantidade_de_ingressos= 10
quantidade_comprada= int(input('digite a quantidade de ingressos que deseja comprar: '))
if quantidade_comprada < 10: print('temos ingressos disponiveis!')
else:
    print('desculpe, não temos ingressos disponiveis.')
# Out:
# digite a quantidade de ingressos que deseja comprar: 11
# desculpe, não temos ingressos disponiveis.

# %%
idade = int(input('Qual a sua idade? '))

if idade >= 18:
    print('recomendamos o filme adulto.')
    quantidade_comprada1 = int(input('Quantos ingressos para o filme adulto você comprou? '))
    if quantidade_comprada1 < 10:
        print('Não temos ingressos disponíveis no momento.')
    else:
        print('Temos ingressos disponíveis para você!')
elif idade >= 12 and idade < 18:
    print('recomendamos o filme infantil.')
    quantidade_comprada2 = int(input('Quantos ingressos para o filme infantil você comprou? '))
    if quantidade_comprada2 > 10:
        print('Não temos ingressos disponíveis no momento.')
    else:
        print('Temos ingressos disponíveis para você!')
else:
    print('Idade não elegível para compra de ingressos de filme adulto ou infantil neste momento.')
# Out:
# Qual a sua idade? 15
# recomendamos o filme infantil.
# Quantos ingressos para o filme infantil você comprou? 13
# Não temos ingressos disponíveis no momento.
